# %% [markdown]
# <a href="https://colab.research.google.com/github/HMendesDev/Projetos-Data-Science/blob/main/KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %% [markdown]
# # Carregando os dados

# %%
arq = "/content/drive/MyDrive/Data Science/Agrupamento/Iris Data Set.csv"

# %%
df =  pd.read_csv(arq, sep=",")

# %% [markdown]
# Visualizando os dados

# %%
df
# Out:
#      sepal_length_in_cm   sepal_width_in_cm  petal_length_in_cm  \
# 0                   5.1                 3.5                 1.4
# 1                   4.9                 3.0                 1.4
# 2                   4.7                 3.2                 1.3
# 3                   4.6                 3.1                 1.5
# 4                   5.0                 3.6                 1.4
# ..                  ...                 ...                 ...
# 145                 6.7                 3.0                 5.2
# 146                 6.3                 2.5                 5.0
# 147                 6.5                 3.0                 5.2
# 148                 6.2                 3.4                 5.4
# 149                 5.9                 3.0                 5.1
#
#      petal_width_in_cm          class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# 4                  0.2     Iris-setosa
# ..                 ...             ...
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Limpeza e Transformação

# %% [markdown]
# Verificando as informações do nosso dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal_length_in_cm  150 non-null    float64
#  1    sepal_width_in_cm  150 non-null    float64
#  2   petal_length_in_cm  150 non-null    float64
#  3   petal_width_in_cm   150 non-null    float64
#  4   class               150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Quantidade de linhas em nosso dataset:

# %%
df.shape[0]
# Out:
# 150

# %% [markdown]
# Quantidade de registros em nosso dataset:

# %%
df.shape[0] * df.shape[1]
# Out:
# 750

# %% [markdown]
# Verificando linhas duplicadas:

# %%
df[df.duplicated()]
# Out:
#      sepal_length_in_cm   sepal_width_in_cm  petal_length_in_cm  \
# 34                  4.9                 3.1                 1.5
# 37                  4.9                 3.1                 1.5
# 142                 5.8                 2.7                 5.1
#
#      petal_width_in_cm          class
# 34                 0.1     Iris-setosa
# 37                 0.1     Iris-setosa
# 142                1.9  Iris-virginica

# %% [markdown]
# Removendo duplicadas:

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [sepal_length_in_cm,  sepal_width_in_cm, petal_length_in_cm, petal_width_in_cm, class ]
# Index: []

# %% [markdown]
# Verificando registros nulos:

# %%
df.isnull().sum()
# Out:
# sepal_length_in_cm    0
#  sepal_width_in_cm    0
# petal_length_in_cm    0
# petal_width_in_cm     0
# class                 0
# dtype: int64
