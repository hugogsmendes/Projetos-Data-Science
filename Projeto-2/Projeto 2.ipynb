# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
from scipy.stats import shapiro,spearmanr,binom

# %%
arq = "201807_CPGF.csv"

# %%
df = pd.read_csv(arq, encoding = "latin-1", delimiter = ";")

# %% [markdown]
# # Entendendo nosso dataset

# %%
#Exibindo as 10 primeiras linhas
df.head(10)
# Out:
#    CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 1                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 2                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 3                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 4                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 5                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 6                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 7                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 8                  63000  ADVOCACIA-GERAL DA UNIAO         63000
# 9                  63000  ADVOCACIA-GERAL DA UNIAO         63000
#
#                                           NOME ÓRGÃO  CÓDIGO UNIDADE GESTORA  \
# 0  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 1  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 2  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 3  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 4  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 5  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 6  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 7  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 8  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
# 9  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...                  110096
#
#                            NOME UNIDADE GESTORA  ANO EXTRATO  MÊS EXTRATO  \
# 0  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 1  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 2  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 3  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 4  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 5  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 6  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 7  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 8  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
# 9  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO         2018            7
#
#      CPF PORTADOR                         NOME PORTADOR  \
# 0  ***.123.415-**         RAIMUNDO NONATO MOREIRA COSTA
# 1  ***.818.625-**              MARIA SEILMA NEVES SOUZA
# 2  ***.492.683-**                  FERNANDO LEITE MATOS
# 3  ***.123.415-**         RAIMUNDO NONATO MOREIRA COSTA
# 4  ***.074.281-**      DANIELA SILVA BORGES DE OLIVEIRA
# 5  ***.562.794-**                    FABIO NOBRE CALIFE
# 6  ***.562.794-**                    FABIO NOBRE CALIFE
# 7  ***.409.845-**     MARCOS VINICIUS BARRETO DE ARAUJO
# 8  ***.449.134-**                SENISE LIRA MONTENEGRO
# 9  ***.716.124-**  TANIA LUCIA RAMOS CAVALCANTI DE LIMA
#
#    CNPJ OU CPF FAVORECIDO                                    NOME FAVORECIDO  \
# 0           1432141000146                           DISTRIBUIDORA GLOBO LTDA
# 1                      -2                                      NAO SE APLICA
# 2           3924361000112                                SHOPPINGRAFICA LTDA
# 3          15596182000182                               PAULO JORGE DA SILVA
# 4                      -2                                      NAO SE APLICA
# 5           7352932000142                   JOAO BOSCO DA SILVA - LAVANDERIA
# 6          14510953000104                      RIDLAV MELO SILVA 02887022474
# 7          11162436000101  MARPEL COMERCIAL DE MATERIAIS PARA ESCRITORIO ...
# 8          11062450000125              E M C XAVIER MANUTENCAO DE EXTINTORES
# 9                      -2                                      NAO SE APLICA
#
#                  TRANSAÇÃO DATA TRANSAÇÃO VALOR TRANSAÇÃO
# 0  COMPRA A/V - R$ - APRES     19/06/2018           99,90
# 1        SAQUE CASH/ATM BB     13/06/2018           90,00
# 2  COMPRA A/V - R$ - APRES     21/06/2018           26,59
# 3  COMPRA A/V - R$ - APRES     20/06/2018           25,00
# 4        SAQUE CASH/ATM BB     30/05/2018          260,00
# 5  COMPRA A/V - R$ - APRES     01/06/2018          100,00
# 6  COMPRA A/V - R$ - APRES     30/05/2018            5,00
# 7  COMPRA A/V - R$ - APRES     15/06/2018          125,80
# 8  COMPRA A/V - R$ - APRES     22/06/2018          120,00
# 9        SAQUE CASH/ATM BB     07/06/2018          250,00

# %% [markdown]
# Nosso dataset trata-se de transações de cartões de orgãos superiores e seus respectivos individuos com o seu valor da transação, a data da compra e o que comprou e claro tem as transações sigilosas.
# O nosso dataset temos o extrato do mês de julho de 2018 (7/2018).

# %% [markdown]
# Vamos verificar agora quais são as variáveis e seus respectivos registros

# %%
df.columns
# Out:
# Index(['CÓDIGO ÓRGÃO SUPERIOR', 'NOME ÓRGÃO SUPERIOR', 'CÓDIGO ÓRGÃO',
#        'NOME ÓRGÃO', 'CÓDIGO UNIDADE GESTORA', 'NOME UNIDADE GESTORA',
#        'ANO EXTRATO', 'MÊS EXTRATO', 'CPF PORTADOR', 'NOME PORTADOR',
#        'CNPJ OU CPF FAVORECIDO', 'NOME FAVORECIDO', 'TRANSAÇÃO',
#        'DATA TRANSAÇÃO', 'VALOR TRANSAÇÃO'],
#       dtype='object')

# %% [markdown]
# Verificando a quantidade de orgãos superiores e orgão que temos de registro

# %%
# Orgãos superiores
df["NOME ÓRGÃO SUPERIOR"].value_counts()
# Out:
# MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO     2366
# MINISTERIO DA EDUCACAO                           1902
# MINISTERIO DA JUSTICA                            1277
# MINISTERIO DA DEFESA                             1170
# PRESIDENCIA DA REPUBLICA                          984
# MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO      765
# MINISTERIO DA FAZENDA                             656
# MINISTERIO DE MINAS E ENERGIA                     409
# MINISTERIO DA SAUDE                               364
# MINISTERIO DO TRABALHO                            286
# MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES     271
# MINISTERIO DA INTEGRACAO NACIONAL                 180
# ADVOCACIA-GERAL DA UNIAO                          146
# MINIST.DOS TRANSP.,PORTOS E AVIACAO CIVIL         116
# MINISTERIO DO TRABALHO E EMPREGO                   76
# MINISTERIO DAS CIDADES                             69
# MINISTERIO DO MEIO AMBIENTE                        67
# MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS      59
# MINISTERIO DA CULTURA                              42
# MINISTERIO DO DESENVOLVIMENTO SOCIAL               32
# MINISTERIO DAS RELACOES EXTERIORES                  9
# MINISTERIO DA JUSTICA E SEGURANçA PUBLICA           8
# MINISTERIO DA TRANSPARENCIA E CGU                   6
# Name: NOME ÓRGÃO SUPERIOR, dtype: int64

# %%
# Orgãos
df["NOME ÓRGÃO"].value_counts()
# Out:
# FUND.INST.BRASILEIRO DE GEOG.E ESTATISTICA                     2329
# DEPARTAMENTO DE POLICIA FEDERAL                                1235
# PRESIDENCIA DA REPUBLICA                                        605
# COMANDO DO EXERCITO                                             585
# MINISTERIO DA FAZENDA - UNIDADES COM VÍNCULO DIRETO             471
#                                                                ...
# AGENCIA ESPACIAL BRASILEIRA - AEB                                 1
# MINISTERIO DA CULTURA - UNIDADES COM VÍNCULO DIRETO               1
# UNIVERSIDADE FEDERAL DO TRIANGULO MINEIRO                         1
# SUPERINT.NACIONAL DE PREVIDENCIA COMPLEMENTAR                     1
# MINISTERIO DE MINAS E ENERGIA - UNIDADES COM VÍNCULO DIRETO       1
# Name: NOME ÓRGÃO, Length: 155, dtype: int64

# %%
# Como nosso dataset trabalha somente com dados de extrato de julho de 2018, então temos as datas de transações dividas no final
# maio e mês de junho
df["DATA TRANSAÇÃO"].value_counts().sort_values(ascending = False)
# Out:
# 21/06/2018    614
# 20/06/2018    563
# 07/06/2018    520
# 06/06/2018    489
# 08/06/2018    477
# 19/06/2018    466
# 13/06/2018    464
# 30/05/2018    462
# 18/06/2018    458
# 11/06/2018    450
# 12/06/2018    448
# 15/06/2018    446
# 14/06/2018    437
# 05/06/2018    420
# 25/06/2018    413
# 04/06/2018    406
# 29/05/2018    373
# 26/06/2018    365
# 28/05/2018    355
# 01/06/2018    275
# 22/06/2018    271
# 25/05/2018     75
# 16/06/2018     52
# 09/06/2018     48
# 23/06/2018     38
# 31/05/2018     34
# 02/06/2018     26
# 17/06/2018     25
# 10/06/2018     17
# 03/06/2018     12
# 24/06/2018     11
# 27/05/2018      7
# 26/05/2018      3
# 27/06/2018      1
# Name: DATA TRANSAÇÃO, dtype: int64

# %%
# Verificando informações das variáveis
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11260 entries, 0 to 11259
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CÓDIGO ÓRGÃO SUPERIOR   11260 non-null  int64
#  1   NOME ÓRGÃO SUPERIOR     11260 non-null  object
#  2   CÓDIGO ÓRGÃO            11260 non-null  int64
#  3   NOME ÓRGÃO              11260 non-null  object
#  4   CÓDIGO UNIDADE GESTORA  11260 non-null  int64
#  5   NOME UNIDADE GESTORA    11260 non-null  object
#  6   ANO EXTRATO             11260 non-null  int64
#  7   MÊS EXTRATO             11260 non-null  int64
#  8   CPF PORTADOR            9521 non-null   object
#  9   NOME PORTADOR           11260 non-null  object
#  10  CNPJ OU CPF FAVORECIDO  11260 non-null  int64
#  11  NOME FAVORECIDO         11260 non-null  object
#  12  TRANSAÇÃO               11260 non-null  object
#  13  DATA TRANSAÇÃO          9521 non-null   object
#  14  VALOR TRANSAÇÃO         11260 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# Certo vamos excluir as colunas "ANO EXTRATO E MÊS EXTRATO", pois apresentam registros como 2018 e 7 (julho) e já sabemos que estamos trabalho com o extrato de julho de 2018

# %%
df.drop(columns = ["ANO EXTRATO","MÊS EXTRATO"], inplace = True)

# %% [markdown]
# Percebemos que nossa variável "DATA TRANSAÇÃO" não está no formato de data, vamos então transformar.

# %%
df["DATA TRANSAÇÃO"] = pd.to_datetime(df["DATA TRANSAÇÃO"], dayfirst = True)
df["DATA TRANSAÇÃO"] = df["DATA TRANSAÇÃO"].dt.strftime("%d/%m/%Y")

# %%
df
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 1                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 2                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 3                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 4                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# ...                      ...                       ...           ...
# 11255                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11256                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11257                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11258                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11259                  20000  PRESIDENCIA DA REPUBLICA         20101
#
#                                               NOME ÓRGÃO  \
# 0      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 1      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 2      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 3      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 4      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# ...                                                  ...
# 11255                           PRESIDENCIA DA REPUBLICA
# 11256                           PRESIDENCIA DA REPUBLICA
# 11257                           PRESIDENCIA DA REPUBLICA
# 11258                           PRESIDENCIA DA REPUBLICA
# 11259                           PRESIDENCIA DA REPUBLICA
#
#        CÓDIGO UNIDADE GESTORA                          NOME UNIDADE GESTORA  \
# 0                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 1                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 2                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 3                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 4                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# ...                       ...                                           ...
# 11255                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11256                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11257                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11258                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11259                  110001                SECRETARIA DE ADMINISTRACAO/PR
#
#          CPF PORTADOR                     NOME PORTADOR  \
# 0      ***.123.415-**     RAIMUNDO NONATO MOREIRA COSTA
# 1      ***.818.625-**          MARIA SEILMA NEVES SOUZA
# 2      ***.492.683-**              FERNANDO LEITE MATOS
# 3      ***.123.415-**     RAIMUNDO NONATO MOREIRA COSTA
# 4      ***.074.281-**  DANIELA SILVA BORGES DE OLIVEIRA
# ...               ...                               ...
# 11255             NaN                          Sigiloso
# 11256             NaN                          Sigiloso
# 11257             NaN                          Sigiloso
# 11258             NaN                          Sigiloso
# 11259  ***.485.441-**         VALDECIR DA SILVA RIBEIRO
#
#        CNPJ OU CPF FAVORECIDO                       NOME FAVORECIDO  \
# 0               1432141000146              DISTRIBUIDORA GLOBO LTDA
# 1                          -2                         NAO SE APLICA
# 2               3924361000112                   SHOPPINGRAFICA LTDA
# 3              15596182000182                  PAULO JORGE DA SILVA
# 4                          -2                         NAO SE APLICA
# ...                       ...                                   ...
# 11255                     -11                              Sigiloso
# 11256                     -11                              Sigiloso
# 11257                     -11                              Sigiloso
# 11258                     -11                              Sigiloso
# 11259           5302222000182  POSTO ALDO SAO JOSE DOS PINHAIS LTDA
#
#                                TRANSAÇÃO DATA TRANSAÇÃO VALOR TRANSAÇÃO
# 0                COMPRA A/V - R$ - APRES     19/06/2018           99,90
# 1                      SAQUE CASH/ATM BB     13/06/2018           90,00
# 2                COMPRA A/V - R$ - APRES     21/06/2018           26,59
# 3                COMPRA A/V - R$ - APRES     20/06/2018           25,00
# 4                      SAQUE CASH/ATM BB     30/05/2018          260,00
# ...                                  ...            ...             ...
# 11255  Informações protegidas por sigilo            NaN           80,80
# 11256  Informações protegidas por sigilo            NaN         1383,59
# 11257  Informações protegidas por sigilo            NaN           62,55
# 11258  Informações protegidas por sigilo            NaN          271,49
# 11259            COMPRA A/V - R$ - APRES     06/06/2018          166,30
#
# [11260 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11260 entries, 0 to 11259
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CÓDIGO ÓRGÃO SUPERIOR   11260 non-null  int64
#  1   NOME ÓRGÃO SUPERIOR     11260 non-null  object
#  2   CÓDIGO ÓRGÃO            11260 non-null  int64
#  3   NOME ÓRGÃO              11260 non-null  object
#  4   CÓDIGO UNIDADE GESTORA  11260 non-null  int64
#  5   NOME UNIDADE GESTORA    11260 non-null  object
#  6   CPF PORTADOR            9521 non-null   object
#  7   NOME PORTADOR           11260 non-null  object
#  8   CNPJ OU CPF FAVORECIDO  11260 non-null  int64
#  9   NOME FAVORECIDO         11260 non-null  object
#  10  TRANSAÇÃO               11260 non-null  object
#  11  DATA TRANSAÇÃO          9521 non-null   object
#  12  VALOR TRANSAÇÃO         11260 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# Certo precisamos agora transformar mais uma coluna, "VALOR TRANSAÇÃO" que temos que passar para tipo númerico

# %%
df["VALOR TRANSAÇÃO"] = df["VALOR TRANSAÇÃO"].str.replace(",",".")

# %%
df["VALOR TRANSAÇÃO"] = pd.to_numeric(df["VALOR TRANSAÇÃO"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11260 entries, 0 to 11259
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CÓDIGO ÓRGÃO SUPERIOR   11260 non-null  int64
#  1   NOME ÓRGÃO SUPERIOR     11260 non-null  object
#  2   CÓDIGO ÓRGÃO            11260 non-null  int64
#  3   NOME ÓRGÃO              11260 non-null  object
#  4   CÓDIGO UNIDADE GESTORA  11260 non-null  int64
#  5   NOME UNIDADE GESTORA    11260 non-null  object
#  6   CPF PORTADOR            9521 non-null   object
#  7   NOME PORTADOR           11260 non-null  object
#  8   CNPJ OU CPF FAVORECIDO  11260 non-null  int64
#  9   NOME FAVORECIDO         11260 non-null  object
#  10  TRANSAÇÃO               11260 non-null  object
#  11  DATA TRANSAÇÃO          9521 non-null   object
#  12  VALOR TRANSAÇÃO         11260 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# Agora vamos verificar o que são os registros nulos nas variáveis "DATA TRANSAÇÃO E CPF PORTADOR"

# %%
df.isna().sum()
# Out:
# CÓDIGO ÓRGÃO SUPERIOR        0
# NOME ÓRGÃO SUPERIOR          0
# CÓDIGO ÓRGÃO                 0
# NOME ÓRGÃO                   0
# CÓDIGO UNIDADE GESTORA       0
# NOME UNIDADE GESTORA         0
# CPF PORTADOR              1739
# NOME PORTADOR                0
# CNPJ OU CPF FAVORECIDO       0
# NOME FAVORECIDO              0
# TRANSAÇÃO                    0
# DATA TRANSAÇÃO            1739
# VALOR TRANSAÇÃO              0
# dtype: int64

# %%
df[df["CPF PORTADOR"].isnull()]
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 7005                   25000     MINISTERIO DA FAZENDA         25915
# 7006                   25000     MINISTERIO DA FAZENDA         25915
# 7007                   25000     MINISTERIO DA FAZENDA         25915
# 7010                   25000     MINISTERIO DA FAZENDA         25915
# 7031                   25000     MINISTERIO DA FAZENDA         25000
# ...                      ...                       ...           ...
# 11254                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11255                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11256                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11257                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11258                  20000  PRESIDENCIA DA REPUBLICA         20101
#
#                                               NOME ÓRGÃO  \
# 7005            FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL
# 7006            FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL
# 7007            FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL
# 7010            FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL
# 7031   MINISTERIO DA FAZENDA - UNIDADES COM VÍNCULO D...
# ...                                                  ...
# 11254                           PRESIDENCIA DA REPUBLICA
# 11255                           PRESIDENCIA DA REPUBLICA
# 11256                           PRESIDENCIA DA REPUBLICA
# 11257                           PRESIDENCIA DA REPUBLICA
# 11258                           PRESIDENCIA DA REPUBLICA
#
#        CÓDIGO UNIDADE GESTORA                           NOME UNIDADE GESTORA  \
# 7005                   170395                 FCDF±SSP ± POLICIA CIVIL DO DF
# 7006                   170395                 FCDF±SSP ± POLICIA CIVIL DO DF
# 7007                   170395                 FCDF±SSP ± POLICIA CIVIL DO DF
# 7010                   170395                 FCDF±SSP ± POLICIA CIVIL DO DF
# 7031                   170339  COORDENACAO-GERAL DE PESQ.INVESTIGACAO DA RFB
# ...                       ...                                            ...
# 11254                  110001                 SECRETARIA DE ADMINISTRACAO/PR
# 11255                  110001                 SECRETARIA DE ADMINISTRACAO/PR
# 11256                  110001                 SECRETARIA DE ADMINISTRACAO/PR
# 11257                  110001                 SECRETARIA DE ADMINISTRACAO/PR
# 11258                  110001                 SECRETARIA DE ADMINISTRACAO/PR
#
#       CPF PORTADOR NOME PORTADOR  CNPJ OU CPF FAVORECIDO NOME FAVORECIDO  \
# 7005           NaN      Sigiloso                     -11        Sigiloso
# 7006           NaN      Sigiloso                     -11        Sigiloso
# 7007           NaN      Sigiloso                     -11        Sigiloso
# 7010           NaN      Sigiloso                     -11        Sigiloso
# 7031           NaN      Sigiloso                     -11        Sigiloso
# ...            ...           ...                     ...             ...
# 11254          NaN      Sigiloso                     -11        Sigiloso
# 11255          NaN      Sigiloso                     -11        Sigiloso
# 11256          NaN      Sigiloso                     -11        Sigiloso
# 11257          NaN      Sigiloso                     -11        Sigiloso
# 11258          NaN      Sigiloso                     -11        Sigiloso
#
#                                TRANSAÇÃO DATA TRANSAÇÃO  VALOR TRANSAÇÃO
# 7005   Informações protegidas por sigilo            NaN           800.00
# 7006   Informações protegidas por sigilo            NaN           500.00
# 7007   Informações protegidas por sigilo            NaN           800.00
# 7010   Informações protegidas por sigilo            NaN           800.00
# 7031   Informações protegidas por sigilo            NaN          1000.00
# ...                                  ...            ...              ...
# 11254  Informações protegidas por sigilo            NaN           137.00
# 11255  Informações protegidas por sigilo            NaN            80.80
# 11256  Informações protegidas por sigilo            NaN          1383.59
# 11257  Informações protegidas por sigilo            NaN            62.55
# 11258  Informações protegidas por sigilo            NaN           271.49
#
# [1739 rows x 13 columns]

# %% [markdown]
# Podemos ver que nossos valores nulos são transações sigilosas, então simples vamos preencher nosso registros ausentes na variável "CPF PORTADOR" com "Sigiloso" igual na variável "NOME PORTADOR" mesmo procedimento na variável "DATA TRANSAÇÃO" vamos colocar igual está na variável "TRANSAÇÃO", pois se trata de uma informação sigilosa.

# %%
condicao = df["CPF PORTADOR"].isnull()
df.loc[condicao, "CPF PORTADOR"] = "Sigiloso"

# %%
df[df["CPF PORTADOR"].isnull()]
# Out:
# Empty DataFrame
# Columns: [CÓDIGO ÓRGÃO SUPERIOR, NOME ÓRGÃO SUPERIOR, CÓDIGO ÓRGÃO, NOME ÓRGÃO, CÓDIGO UNIDADE GESTORA, NOME UNIDADE GESTORA, CPF PORTADOR, NOME PORTADOR, CNPJ OU CPF FAVORECIDO, NOME FAVORECIDO, TRANSAÇÃO, DATA TRANSAÇÃO, VALOR TRANSAÇÃO]
# Index: []

# %%
condicao2 = df["DATA TRANSAÇÃO"].isnull()
df.loc[condicao2, "DATA TRANSAÇÃO"] = "Informações protegidas por sigilo"

# %%
df[df["DATA TRANSAÇÃO"].isnull()]
# Out:
# Empty DataFrame
# Columns: [CÓDIGO ÓRGÃO SUPERIOR, NOME ÓRGÃO SUPERIOR, CÓDIGO ÓRGÃO, NOME ÓRGÃO, CÓDIGO UNIDADE GESTORA, NOME UNIDADE GESTORA, CPF PORTADOR, NOME PORTADOR, CNPJ OU CPF FAVORECIDO, NOME FAVORECIDO, TRANSAÇÃO, DATA TRANSAÇÃO, VALOR TRANSAÇÃO]
# Index: []

# %% [markdown]
# Certo valores nulos tratados

# %%
df
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 1                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 2                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 3                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 4                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# ...                      ...                       ...           ...
# 11255                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11256                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11257                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11258                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11259                  20000  PRESIDENCIA DA REPUBLICA         20101
#
#                                               NOME ÓRGÃO  \
# 0      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 1      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 2      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 3      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 4      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# ...                                                  ...
# 11255                           PRESIDENCIA DA REPUBLICA
# 11256                           PRESIDENCIA DA REPUBLICA
# 11257                           PRESIDENCIA DA REPUBLICA
# 11258                           PRESIDENCIA DA REPUBLICA
# 11259                           PRESIDENCIA DA REPUBLICA
#
#        CÓDIGO UNIDADE GESTORA                          NOME UNIDADE GESTORA  \
# 0                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 1                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 2                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 3                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 4                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# ...                       ...                                           ...
# 11255                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11256                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11257                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11258                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11259                  110001                SECRETARIA DE ADMINISTRACAO/PR
#
#          CPF PORTADOR                     NOME PORTADOR  \
# 0      ***.123.415-**     RAIMUNDO NONATO MOREIRA COSTA
# 1      ***.818.625-**          MARIA SEILMA NEVES SOUZA
# 2      ***.492.683-**              FERNANDO LEITE MATOS
# 3      ***.123.415-**     RAIMUNDO NONATO MOREIRA COSTA
# 4      ***.074.281-**  DANIELA SILVA BORGES DE OLIVEIRA
# ...               ...                               ...
# 11255        Sigiloso                          Sigiloso
# 11256        Sigiloso                          Sigiloso
# 11257        Sigiloso                          Sigiloso
# 11258        Sigiloso                          Sigiloso
# 11259  ***.485.441-**         VALDECIR DA SILVA RIBEIRO
#
#        CNPJ OU CPF FAVORECIDO                       NOME FAVORECIDO  \
# 0               1432141000146              DISTRIBUIDORA GLOBO LTDA
# 1                          -2                         NAO SE APLICA
# 2               3924361000112                   SHOPPINGRAFICA LTDA
# 3              15596182000182                  PAULO JORGE DA SILVA
# 4                          -2                         NAO SE APLICA
# ...                       ...                                   ...
# 11255                     -11                              Sigiloso
# 11256                     -11                              Sigiloso
# 11257                     -11                              Sigiloso
# 11258                     -11                              Sigiloso
# 11259           5302222000182  POSTO ALDO SAO JOSE DOS PINHAIS LTDA
#
#                                TRANSAÇÃO                     DATA TRANSAÇÃO  \
# 0                COMPRA A/V - R$ - APRES                         19/06/2018
# 1                      SAQUE CASH/ATM BB                         13/06/2018
# 2                COMPRA A/V - R$ - APRES                         21/06/2018
# 3                COMPRA A/V - R$ - APRES                         20/06/2018
# 4                      SAQUE CASH/ATM BB                         30/05/2018
# ...                                  ...                                ...
# 11255  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11256  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11257  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11258  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11259            COMPRA A/V - R$ - APRES                         06/06/2018
#
#        VALOR TRANSAÇÃO
# 0                99.90
# 1                90.00
# 2                26.59
# 3                25.00
# 4               260.00
# ...                ...
# 11255            80.80
# 11256          1383.59
# 11257            62.55
# 11258           271.49
# 11259           166.30
#
# [11260 rows x 13 columns]

# %% [markdown]
# Podemos perceber também que nossa variável "CNPJ OU CPF FAVORECIDO" apresenta valores "sujos", podemos deduzir que não foi preenchido corretamente, então onde temos os valores "sujos", vamos preencher com "Sem informação".

# %%
condicao3 = df["CNPJ OU CPF FAVORECIDO"] < 0

# %%
df.loc[condicao3, "CNPJ OU CPF FAVORECIDO"] = "Sem informação"

# %%
df
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 1                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 2                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 3                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 4                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# ...                      ...                       ...           ...
# 11255                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11256                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11257                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11258                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11259                  20000  PRESIDENCIA DA REPUBLICA         20101
#
#                                               NOME ÓRGÃO  \
# 0      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 1      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 2      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 3      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 4      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# ...                                                  ...
# 11255                           PRESIDENCIA DA REPUBLICA
# 11256                           PRESIDENCIA DA REPUBLICA
# 11257                           PRESIDENCIA DA REPUBLICA
# 11258                           PRESIDENCIA DA REPUBLICA
# 11259                           PRESIDENCIA DA REPUBLICA
#
#        CÓDIGO UNIDADE GESTORA                          NOME UNIDADE GESTORA  \
# 0                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 1                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 2                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 3                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 4                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# ...                       ...                                           ...
# 11255                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11256                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11257                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11258                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11259                  110001                SECRETARIA DE ADMINISTRACAO/PR
#
#          CPF PORTADOR                     NOME PORTADOR  \
# 0      ***.123.415-**     RAIMUNDO NONATO MOREIRA COSTA
# 1      ***.818.625-**          MARIA SEILMA NEVES SOUZA
# 2      ***.492.683-**              FERNANDO LEITE MATOS
# 3      ***.123.415-**     RAIMUNDO NONATO MOREIRA COSTA
# 4      ***.074.281-**  DANIELA SILVA BORGES DE OLIVEIRA
# ...               ...                               ...
# 11255        Sigiloso                          Sigiloso
# 11256        Sigiloso                          Sigiloso
# 11257        Sigiloso                          Sigiloso
# 11258        Sigiloso                          Sigiloso
# 11259  ***.485.441-**         VALDECIR DA SILVA RIBEIRO
#
#       CNPJ OU CPF FAVORECIDO                       NOME FAVORECIDO  \
# 0              1432141000146              DISTRIBUIDORA GLOBO LTDA
# 1             Sem informação                         NAO SE APLICA
# 2              3924361000112                   SHOPPINGRAFICA LTDA
# 3             15596182000182                  PAULO JORGE DA SILVA
# 4             Sem informação                         NAO SE APLICA
# ...                      ...                                   ...
# 11255         Sem informação                              Sigiloso
# 11256         Sem informação                              Sigiloso
# 11257         Sem informação                              Sigiloso
# 11258         Sem informação                              Sigiloso
# 11259          5302222000182  POSTO ALDO SAO JOSE DOS PINHAIS LTDA
#
#                                TRANSAÇÃO                     DATA TRANSAÇÃO  \
# 0                COMPRA A/V - R$ - APRES                         19/06/2018
# 1                      SAQUE CASH/ATM BB                         13/06/2018
# 2                COMPRA A/V - R$ - APRES                         21/06/2018
# 3                COMPRA A/V - R$ - APRES                         20/06/2018
# 4                      SAQUE CASH/ATM BB                         30/05/2018
# ...                                  ...                                ...
# 11255  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11256  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11257  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11258  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11259            COMPRA A/V - R$ - APRES                         06/06/2018
#
#        VALOR TRANSAÇÃO
# 0                99.90
# 1                90.00
# 2                26.59
# 3                25.00
# 4               260.00
# ...                ...
# 11255            80.80
# 11256          1383.59
# 11257            62.55
# 11258           271.49
# 11259           166.30
#
# [11260 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11260 entries, 0 to 11259
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CÓDIGO ÓRGÃO SUPERIOR   11260 non-null  int64
#  1   NOME ÓRGÃO SUPERIOR     11260 non-null  object
#  2   CÓDIGO ÓRGÃO            11260 non-null  int64
#  3   NOME ÓRGÃO              11260 non-null  object
#  4   CÓDIGO UNIDADE GESTORA  11260 non-null  int64
#  5   NOME UNIDADE GESTORA    11260 non-null  object
#  6   CPF PORTADOR            11260 non-null  object
#  7   NOME PORTADOR           11260 non-null  object
#  8   CNPJ OU CPF FAVORECIDO  11260 non-null  object
#  9   NOME FAVORECIDO         11260 non-null  object
#  10  TRANSAÇÃO               11260 non-null  object
#  11  DATA TRANSAÇÃO          11260 non-null  object
#  12  VALOR TRANSAÇÃO         11260 non-null  float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# Vamos analisar primeiro as transações sigilosas

# %%
df_sigilosa = df[df["CPF PORTADOR"] == "Sigiloso"].copy()

# %%
df_sigilosa
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 7005                   25000     MINISTERIO DA FAZENDA         25915
# 7006                   25000     MINISTERIO DA FAZENDA         25915
# 7007                   25000     MINISTERIO DA FAZENDA         25915
# 7010                   25000     MINISTERIO DA FAZENDA         25915
# 7031                   25000     MINISTERIO DA FAZENDA         25000
# ...                      ...                       ...           ...
# 11254                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11255                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11256                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11257                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11258                  20000  PRESIDENCIA DA REPUBLICA         20101
#
#                                               NOME ÓRGÃO  \
# 7005            FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL
# 7006            FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL
# 7007            FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL
# 7010            FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL
# 7031   MINISTERIO DA FAZENDA - UNIDADES COM VÍNCULO D...
# ...                                                  ...
# 11254                           PRESIDENCIA DA REPUBLICA
# 11255                           PRESIDENCIA DA REPUBLICA
# 11256                           PRESIDENCIA DA REPUBLICA
# 11257                           PRESIDENCIA DA REPUBLICA
# 11258                           PRESIDENCIA DA REPUBLICA
#
#        CÓDIGO UNIDADE GESTORA                           NOME UNIDADE GESTORA  \
# 7005                   170395                 FCDF±SSP ± POLICIA CIVIL DO DF
# 7006                   170395                 FCDF±SSP ± POLICIA CIVIL DO DF
# 7007                   170395                 FCDF±SSP ± POLICIA CIVIL DO DF
# 7010                   170395                 FCDF±SSP ± POLICIA CIVIL DO DF
# 7031                   170339  COORDENACAO-GERAL DE PESQ.INVESTIGACAO DA RFB
# ...                       ...                                            ...
# 11254                  110001                 SECRETARIA DE ADMINISTRACAO/PR
# 11255                  110001                 SECRETARIA DE ADMINISTRACAO/PR
# 11256                  110001                 SECRETARIA DE ADMINISTRACAO/PR
# 11257                  110001                 SECRETARIA DE ADMINISTRACAO/PR
# 11258                  110001                 SECRETARIA DE ADMINISTRACAO/PR
#
#       CPF PORTADOR NOME PORTADOR CNPJ OU CPF FAVORECIDO NOME FAVORECIDO  \
# 7005      Sigiloso      Sigiloso         Sem informação        Sigiloso
# 7006      Sigiloso      Sigiloso         Sem informação        Sigiloso
# 7007      Sigiloso      Sigiloso         Sem informação        Sigiloso
# 7010      Sigiloso      Sigiloso         Sem informação        Sigiloso
# 7031      Sigiloso      Sigiloso         Sem informação        Sigiloso
# ...            ...           ...                    ...             ...
# 11254     Sigiloso      Sigiloso         Sem informação        Sigiloso
# 11255     Sigiloso      Sigiloso         Sem informação        Sigiloso
# 11256     Sigiloso      Sigiloso         Sem informação        Sigiloso
# 11257     Sigiloso      Sigiloso         Sem informação        Sigiloso
# 11258     Sigiloso      Sigiloso         Sem informação        Sigiloso
#
#                                TRANSAÇÃO                     DATA TRANSAÇÃO  \
# 7005   Informações protegidas por sigilo  Informações protegidas por sigilo
# 7006   Informações protegidas por sigilo  Informações protegidas por sigilo
# 7007   Informações protegidas por sigilo  Informações protegidas por sigilo
# 7010   Informações protegidas por sigilo  Informações protegidas por sigilo
# 7031   Informações protegidas por sigilo  Informações protegidas por sigilo
# ...                                  ...                                ...
# 11254  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11255  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11256  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11257  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11258  Informações protegidas por sigilo  Informações protegidas por sigilo
#
#        VALOR TRANSAÇÃO
# 7005            800.00
# 7006            500.00
# 7007            800.00
# 7010            800.00
# 7031           1000.00
# ...                ...
# 11254           137.00
# 11255            80.80
# 11256          1383.59
# 11257            62.55
# 11258           271.49
#
# [1739 rows x 13 columns]

# %%
plt.figure(figsize=(12,8))
ax = sns.countplot(x = "CPF PORTADOR",data = df_sigilosa)
ax.bar_label(ax.containers[0], fontsize=12, color='black', padding=5)
plt.xlabel("")
plt.ylabel("Quantidade")
plt.title("Transações Sigilosos")
plt.show()

# %%
# Valor gasto pela transações sigilosas
df_sigilosa["VALOR TRANSAÇÃO"].sum()
# Out:
# 1749347.32

# %%
df_sigilosa.describe()
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  CÓDIGO UNIDADE GESTORA  \
# count            1739.000000   1739.000000             1739.000000
# mean            26661.874641  26769.101783           170335.658999
# std              4703.350805   4706.253944            42402.947496
# min             20000.000000  20101.000000           110001.000000
# 25%             20000.000000  20101.000000           110538.000000
# 50%             30000.000000  30108.000000           200344.000000
# 75%             30000.000000  30108.000000           200372.000000
# max             30000.000000  30108.000000           200406.000000
#
#        VALOR TRANSAÇÃO
# count      1739.000000
# mean       1005.950155
# std        2169.639496
# min           4.200000
# 25%         333.180000
# 50%        1000.000000
# 75%        1000.000000
# max       30591.000000

# %%
df_sigilosa1 = df_sigilosa.groupby("NOME ÓRGÃO SUPERIOR")["VALOR TRANSAÇÃO"].agg(["count","sum"]).reset_index().sort_values(by = "sum", ascending = False)

# %%
df_sigilosa1.rename(columns = {"count":"Transações", "sum":"Valor Total"},inplace=True)

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x=df_sigilosa1["NOME ÓRGÃO SUPERIOR"], y = df_sigilosa1["Valor Total"])
ax.bar_label(ax.containers[0], fontsize=12, color='black', padding=5)
plt.xlabel("")
plt.ylabel("Valor Transacional Gasto")
plt.title("Valor Gasto por cada orgão superior em transações sigilosas")
plt.show()

# %%
df_sigilosa1
# Out:
#         NOME ÓRGÃO SUPERIOR  Transações  Valor Total
# 1     MINISTERIO DA JUSTICA        1154    896070.59
# 2  PRESIDENCIA DA REPUBLICA         576    846276.73
# 0     MINISTERIO DA FAZENDA           9      7000.00

# %%
df_sigilosa2 = df_sigilosa.groupby(["NOME ÓRGÃO SUPERIOR","NOME ÓRGÃO"])["VALOR TRANSAÇÃO"].agg(["count","sum"]).reset_index().sort_values(by = "sum", ascending = False)

# %%
df_sigilosa2.rename(columns = {"count":"Transações", "sum":"Valor Total"})
# Out:
#         NOME ÓRGÃO SUPERIOR  \
# 2     MINISTERIO DA JUSTICA
# 3  PRESIDENCIA DA REPUBLICA
# 1     MINISTERIO DA FAZENDA
# 0     MINISTERIO DA FAZENDA
#
#                                           NOME ÓRGÃO  Transações  Valor Total
# 2                    DEPARTAMENTO DE POLICIA FEDERAL        1154    896070.59
# 3                           PRESIDENCIA DA REPUBLICA         576    846276.73
# 1  MINISTERIO DA FAZENDA - UNIDADES COM VÍNCULO D...           5      4100.00
# 0           FUNDO CONSTITUCIONAL DO DISTRITO FEDERAL           4      2900.00

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=df_sigilosa["VALOR TRANSAÇÃO"])
plt.title("Box Plot somente de Transações sigilosas")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x=df_sigilosa["VALOR TRANSAÇÃO"], y = df_sigilosa["NOME ÓRGÃO SUPERIOR"])
plt.xlabel("")
plt.title("Box Plot somente de Transações sigilosa por Orgão Superior")
plt.show()

# %%
IC = df_sigilosa["VALOR TRANSAÇÃO"].quantile(0.75) - df_sigilosa["VALOR TRANSAÇÃO"].quantile(0.25)
formula = df_sigilosa["VALOR TRANSAÇÃO"].quantile(0.75) + (1.5 * IC)

# %%
condicao = df_sigilosa["VALOR TRANSAÇÃO"] > formula

# %%
df_sigilosa3 = df_sigilosa.loc[condicao, ].copy()

# %%
df_sigilosa3.describe()
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  CÓDIGO UNIDADE GESTORA  \
# count              63.000000     63.000000               63.000000
# mean            22857.142857  22960.142857           135973.158730
# std              4553.825555   4557.013233            41053.693775
# min             20000.000000  20101.000000           110001.000000
# 25%             20000.000000  20101.000000           110001.000000
# 50%             20000.000000  20101.000000           110538.000000
# 75%             30000.000000  30108.000000           200354.000000
# max             30000.000000  30108.000000           200384.000000
#
#        VALOR TRANSAÇÃO
# count        63.000000
# mean       8870.547619
# std        7908.950181
# min        2025.000000
# 25%        2583.740000
# 50%        4166.000000
# 75%       20000.000000
# max       30591.000000

# %%
maior_transacao = df_sigilosa3["VALOR TRANSAÇÃO"] == df_sigilosa3["VALOR TRANSAÇÃO"].max()
df_sigilosa3.loc[maior_transacao, :]
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 11027                  20000  PRESIDENCIA DA REPUBLICA         20101
#
#                      NOME ÓRGÃO  CÓDIGO UNIDADE GESTORA  \
# 11027  PRESIDENCIA DA REPUBLICA                  110001
#
#                  NOME UNIDADE GESTORA CPF PORTADOR NOME PORTADOR  \
# 11027  SECRETARIA DE ADMINISTRACAO/PR     Sigiloso      Sigiloso
#
#       CNPJ OU CPF FAVORECIDO NOME FAVORECIDO  \
# 11027         Sem informação        Sigiloso
#
#                                TRANSAÇÃO                     DATA TRANSAÇÃO  \
# 11027  Informações protegidas por sigilo  Informações protegidas por sigilo
#
#        VALOR TRANSAÇÃO
# 11027          30591.0

# %%
df_sigilosa4 = df_sigilosa.groupby("NOME ÓRGÃO SUPERIOR")["VALOR TRANSAÇÃO"].agg(["count","mean","median"]).reset_index().sort_values(by = "mean", ascending = False)

# %%
df_sigilosa4.rename(columns = {"count":"Transações","mean":"Média de Transação","median":"Mediana"})
# Out:
#         NOME ÓRGÃO SUPERIOR  Transações  Média de Transação  Mediana
# 2  PRESIDENCIA DA REPUBLICA         576         1469.230434   831.07
# 0     MINISTERIO DA FAZENDA           9          777.777778   800.00
# 1     MINISTERIO DA JUSTICA        1154          776.490979  1000.00

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x=df_sigilosa4["NOME ÓRGÃO SUPERIOR"], y = df_sigilosa4["mean"], label = "")
ax.bar_label(ax.containers[0], fontsize=12, color='black', padding=5)
plt.xlabel("")
plt.ylabel("Média de Valor Transacional Gasto")
plt.title("Média de Gasto por cada orgão superior em transações sigilosas")
plt.show()

# %% [markdown]
# Vamos fazer um teste de hipotese para descobrir se nossa média amostral de transação do orgão Presidencia da Republica com transações sigilosas é igual a média populacional de transação de toda a população do orgão Presidencia da Republica.

# %% [markdown]
# H0 = Nossa média de transações sigilosas do orgão Presidencia da Republica é igual a média transacional de todo o orgão Presidencia da Republica
# H1 = Nossa média de transações sigilosas do orgão Presidencia da Republica é diferente da média transacional de todo o orgão Presidencia da Republica

# %%
media_populacional = df["VALOR TRANSAÇÃO"][df["NOME ÓRGÃO SUPERIOR"] == "PRESIDENCIA DA REPUBLICA"].mean()
nivel_significancia = 0.05

# %%
estatistica_t, p_valor = stats.ttest_1samp(
    a=df_sigilosa["VALOR TRANSAÇÃO"][df_sigilosa["NOME ÓRGÃO SUPERIOR"] == "PRESIDENCIA DA REPUBLICA"],
    popmean=media_populacional
)

# %%
if p_valor > nivel_significancia:
    print("Não temos evidencias suficientes para rejeitar a Hipotese nula que indica que as médias são iguais")
else:
    print("Rejeitamos a Hipotese nula e aceitamos estatisticamente a Hipotes alternativa que nossa médias são diferentes")
# Out:
# Rejeitamos a Hipotese nula e aceitamos estatisticamente a Hipotes alternativa que nossa médias são diferentes

# %%
if estatistica_t > 0:
    print("Nossa média amostral é maior que nossa média populacional")
else:
    print("Nossa média amostral é menor que nossa média populacional")
# Out:
# Nossa média amostral é maior que nossa média populacional

# %% [markdown]
# Então chegamos a um ponto que podemos garantir tanto visualmente como estatisticamente que média de transações amostral do orgão Presidencia da Republica com informações sigilosas é maior do que a média de transações populacional de todas as transações do orgão Presidencia da Republica.

# %%
df
# Out:
#        CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 1                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 2                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 3                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# 4                      63000  ADVOCACIA-GERAL DA UNIAO         63000
# ...                      ...                       ...           ...
# 11255                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11256                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11257                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11258                  20000  PRESIDENCIA DA REPUBLICA         20101
# 11259                  20000  PRESIDENCIA DA REPUBLICA         20101
#
#                                               NOME ÓRGÃO  \
# 0      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 1      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 2      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 3      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# 4      ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...
# ...                                                  ...
# 11255                           PRESIDENCIA DA REPUBLICA
# 11256                           PRESIDENCIA DA REPUBLICA
# 11257                           PRESIDENCIA DA REPUBLICA
# 11258                           PRESIDENCIA DA REPUBLICA
# 11259                           PRESIDENCIA DA REPUBLICA
#
#        CÓDIGO UNIDADE GESTORA                          NOME UNIDADE GESTORA  \
# 0                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 1                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 2                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 3                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# 4                      110096  SUPERINTENDENCIA ADMINISTRACAO EM PERNAMBUCO
# ...                       ...                                           ...
# 11255                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11256                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11257                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11258                  110001                SECRETARIA DE ADMINISTRACAO/PR
# 11259                  110001                SECRETARIA DE ADMINISTRACAO/PR
#
#          CPF PORTADOR                     NOME PORTADOR  \
# 0      ***.123.415-**     RAIMUNDO NONATO MOREIRA COSTA
# 1      ***.818.625-**          MARIA SEILMA NEVES SOUZA
# 2      ***.492.683-**              FERNANDO LEITE MATOS
# 3      ***.123.415-**     RAIMUNDO NONATO MOREIRA COSTA
# 4      ***.074.281-**  DANIELA SILVA BORGES DE OLIVEIRA
# ...               ...                               ...
# 11255        Sigiloso                          Sigiloso
# 11256        Sigiloso                          Sigiloso
# 11257        Sigiloso                          Sigiloso
# 11258        Sigiloso                          Sigiloso
# 11259  ***.485.441-**         VALDECIR DA SILVA RIBEIRO
#
#       CNPJ OU CPF FAVORECIDO                       NOME FAVORECIDO  \
# 0              1432141000146              DISTRIBUIDORA GLOBO LTDA
# 1             Sem informação                         NAO SE APLICA
# 2              3924361000112                   SHOPPINGRAFICA LTDA
# 3             15596182000182                  PAULO JORGE DA SILVA
# 4             Sem informação                         NAO SE APLICA
# ...                      ...                                   ...
# 11255         Sem informação                              Sigiloso
# 11256         Sem informação                              Sigiloso
# 11257         Sem informação                              Sigiloso
# 11258         Sem informação                              Sigiloso
# 11259          5302222000182  POSTO ALDO SAO JOSE DOS PINHAIS LTDA
#
#                                TRANSAÇÃO                     DATA TRANSAÇÃO  \
# 0                COMPRA A/V - R$ - APRES                         19/06/2018
# 1                      SAQUE CASH/ATM BB                         13/06/2018
# 2                COMPRA A/V - R$ - APRES                         21/06/2018
# 3                COMPRA A/V - R$ - APRES                         20/06/2018
# 4                      SAQUE CASH/ATM BB                         30/05/2018
# ...                                  ...                                ...
# 11255  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11256  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11257  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11258  Informações protegidas por sigilo  Informações protegidas por sigilo
# 11259            COMPRA A/V - R$ - APRES                         06/06/2018
#
#        VALOR TRANSAÇÃO
# 0                99.90
# 1                90.00
# 2                26.59
# 3                25.00
# 4               260.00
# ...                ...
# 11255            80.80
# 11256          1383.59
# 11257            62.55
# 11258           271.49
# 11259           166.30
#
# [11260 rows x 13 columns]

# %%
df_geral = df.groupby("NOME ÓRGÃO SUPERIOR")["VALOR TRANSAÇÃO"].agg(["count","sum"]).reset_index().sort_values(by="sum",ascending=False)

# %%
df_geral.rename(columns = {"sum":"Valor Total","count":"Transações"},inplace=True)

# %%
df_geral
# Out:
#                               NOME ÓRGÃO SUPERIOR  Transações  Valor Total
# 22                       PRESIDENCIA DA REPUBLICA         984    949605.14
# 11                          MINISTERIO DA JUSTICA        1277    927984.40
# 3    MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO        2366    535143.88
# 8                          MINISTERIO DA EDUCACAO        1902    459312.82
# 7                            MINISTERIO DA DEFESA        1170    374416.13
# 1    MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO         765    163804.18
# 9                           MINISTERIO DA FAZENDA         656    134852.65
# 13                            MINISTERIO DA SAUDE         364    114788.81
# 17                  MINISTERIO DE MINAS E ENERGIA         409     79762.89
# 4   MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES         271     61405.10
# 20                         MINISTERIO DO TRABALHO         286     54772.25
# 10              MINISTERIO DA INTEGRACAO NACIONAL         180     34149.96
# 19                    MINISTERIO DO MEIO AMBIENTE          67     33570.26
# 0                        ADVOCACIA-GERAL DA UNIAO         146     22048.14
# 5       MINIST.DOS TRANSP.,PORTOS E AVIACAO CIVIL         116     20886.22
# 21               MINISTERIO DO TRABALHO E EMPREGO          76     16351.88
# 2   MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS          59     15805.02
# 15                         MINISTERIO DAS CIDADES          69     13098.73
# 18           MINISTERIO DO DESENVOLVIMENTO SOCIAL          32      9151.07
# 6                           MINISTERIO DA CULTURA          42      7828.54
# 12      MINISTERIO DA JUSTICA E SEGURANçA PUBLICA           8      2101.00
# 14              MINISTERIO DA TRANSPARENCIA E CGU           6      2011.86
# 16             MINISTERIO DAS RELACOES EXTERIORES           9       573.34

# %% [markdown]
# Podemos identificar que o orgão Presidencia da Republica é o que tem mais gasto em transações, mesmo tendo um volume menor de transações.

# %%
valor_total_geral = df_geral["Valor Total"][df_geral["NOME ÓRGÃO SUPERIOR"] == "PRESIDENCIA DA REPUBLICA"]
valor_total_sigiloso = df_sigilosa1["Valor Total"][df_sigilosa1["NOME ÓRGÃO SUPERIOR"] == "PRESIDENCIA DA REPUBLICA"]

# %%
transacoes_total_geral = df_geral["Transações"][df_geral["NOME ÓRGÃO SUPERIOR"] == "PRESIDENCIA DA REPUBLICA"]
transacoes_total_sigiloso = df_sigilosa1["Transações"][df_sigilosa1["NOME ÓRGÃO SUPERIOR"] == "PRESIDENCIA DA REPUBLICA"]

# %%
df_presidencia = pd.DataFrame({"Orgão":"Presidencia da Republica","Sigiloso":["Não","Sim"],
                               "Transações":[(transacoes_total_geral.item()-transacoes_total_sigiloso.item()),
                                transacoes_total_sigiloso.item()],
                              "Valor Total":[(valor_total_geral.item()-valor_total_sigiloso.item()),valor_total_sigiloso.item()]})

# %%
df_presidencia["Valor Total"] = round(df_presidencia["Valor Total"],2)

# %%
df_presidencia
# Out:
#                       Orgão Sigiloso  Transações  Valor Total
# 0  Presidencia da Republica      Não         408    103328.41
# 1  Presidencia da Republica      Sim         576    846276.73

# %%
plt.figure(figsize=(15,8))
ax = sns.barplot(x=df_presidencia["Sigiloso"], y =df_presidencia["Valor Total"])
ax.bar_label(ax.containers[0], fontsize=12, color='black', padding=5)
plt.ylabel("Valor Total")
plt.title("Valor total gasto pelo orgão Presidencia da Republica por transação sigilosa ou não")
plt.show()

# %% [markdown]
# Podemos ver que o valor gasto pelo orgão presidencia da republica com transações sigilosa é muito superior a outras transações que não são sigilosas do orgão presidencia da republica.

# %%
print(f"Valot total gasto por transações sigilosas R${df_sigilosa['VALOR TRANSAÇÃO'].sum()}")
# Out:
# Valot total gasto por transações sigilosas R$1749347.32

# %%
print(f"Valot total gasto por transações que não são sigilosas R${df['VALOR TRANSAÇÃO'][df['CPF PORTADOR'] != 'Sigiloso'].sum()}")
# Out:
# Valot total gasto por transações que não são sigilosas R$2284076.95

# %%
df_datas = df.groupby("DATA TRANSAÇÃO")["VALOR TRANSAÇÃO"].agg(["count","sum"]).reset_index().sort_values(by = "sum",ascending=False)

# %%
df_datas.drop(34,inplace=True)

# %%
df_datas["DATA TRANSAÇÃO"] = pd.to_datetime(df_datas["DATA TRANSAÇÃO"], dayfirst=True)

# %%
df_datas = df_datas.set_index('DATA TRANSAÇÃO')

# %%
df_datas = df_datas.sort_index()

# %%
plt.figure(figsize=(12,6))
df_datas["sum"].plot(color="crimson", marker='*', title="Valor Total Transacionado por Dia")
plt.ylabel("Valor Total")
plt.show()

# %%
df_datas
# Out:
#                 count        sum
# DATA TRANSAÇÃO
# 2018-05-25         75   25031.00
# 2018-05-26          3    2344.19
# 2018-05-27          7    3094.34
# 2018-05-28        355   97127.83
# 2018-05-29        373   94438.19
# 2018-05-30        462  120353.91
# 2018-05-31         34    7363.51
# 2018-06-01        275   77305.96
# 2018-06-02         26    6780.27
# 2018-06-03         12    4743.12
# 2018-06-04        406   96292.58
# 2018-06-05        420   91373.42
# 2018-06-06        489  107563.88
# 2018-06-07        520  117863.63
# 2018-06-08        477  119740.57
# 2018-06-09         48   14373.50
# 2018-06-10         17    8011.46
# 2018-06-11        450  109145.31
# 2018-06-12        448   95815.76
# 2018-06-13        464  114935.81
# 2018-06-14        437   93491.67
# 2018-06-15        446  122626.13
# 2018-06-16         52   14088.60
# 2018-06-17         25    6247.72
# 2018-06-18        458  100753.86
# 2018-06-19        466  106355.60
# 2018-06-20        563  128006.24
# 2018-06-21        614  148074.98
# 2018-06-22        271   66381.25
# 2018-06-23         38    8452.04
# 2018-06-24         11    2222.72
# 2018-06-25        413  104149.19
# 2018-06-26        365   69471.14
# 2018-06-27          1      57.57

# %% [markdown]
# Podemos acompanhar quanto foi o valor total de transações por dia e claro filtrando somente transações que não foram sigilosas, pois não conseguimos saber as datas dessas transações

# %% [markdown]
# O dia com mais valor gasto foi 21/6 com R$ 148.074,00 reias gastos e uma quantidade de 614 transações. Vamos explorar mais esse dia, quem foi o orgão que mais gasto esse dia.

# %%
df_dia_mais_gasto = df[df["DATA TRANSAÇÃO"] == "21/06/2018"].copy()

# %%
df_dia_mais_gasto2 = df_dia_mais_gasto.groupby("NOME ÓRGÃO SUPERIOR")["VALOR TRANSAÇÃO"].agg(["sum","count"]).reset_index().sort_values(by="sum",ascending=False)

# %%
df_dia_mais_gasto2.rename(columns = {"sum":"Valor Total","count":"Transações"}, inplace = True)

# %%
df_dia_mais_gasto2
# Out:
#                               NOME ÓRGÃO SUPERIOR  Valor Total  Transações
# 7                            MINISTERIO DA DEFESA     30251.11         105
# 3    MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO     27315.63         126
# 8                          MINISTERIO DA EDUCACAO     24958.34         105
# 1    MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO     13722.63          64
# 12                            MINISTERIO DA SAUDE     10200.62          25
# 9                           MINISTERIO DA FAZENDA      7465.26          47
# 20                       PRESIDENCIA DA REPUBLICA      5822.27          22
# 4   MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES      5755.78          18
# 15                  MINISTERIO DE MINAS E ENERGIA      5352.94          29
# 10              MINISTERIO DA INTEGRACAO NACIONAL      4009.29          14
# 17                    MINISTERIO DO MEIO AMBIENTE      3791.90           3
# 2   MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS      1726.58           7
# 13                         MINISTERIO DAS CIDADES      1409.46          12
# 11                          MINISTERIO DA JUSTICA      1267.79           6
# 5       MINIST.DOS TRANSP.,PORTOS E AVIACAO CIVIL      1165.06           8
# 18                         MINISTERIO DO TRABALHO       997.04           8
# 19               MINISTERIO DO TRABALHO E EMPREGO       909.31           4
# 0                        ADVOCACIA-GERAL DA UNIAO       894.63           6
# 6                           MINISTERIO DA CULTURA       469.90           2
# 14             MINISTERIO DAS RELACOES EXTERIORES       437.54           2
# 16           MINISTERIO DO DESENVOLVIMENTO SOCIAL       151.90           1

# %% [markdown]
# Podemos ver que nesse dia 21/06 o orgão responsável por ter o maior gasto foi o Ministério da Defesa com R$ 30.251,11 gasto e 105 transações. Vamos explorar mais esse dia e o orgão responsável por esse gasto.

# %%
df_dia_mais_gasto3 = df_dia_mais_gasto[df_dia_mais_gasto["NOME ÓRGÃO SUPERIOR"] == "MINISTERIO DA DEFESA"]

# %%
df_dia_mais_gasto4 = df_dia_mais_gasto3.groupby(["NOME ÓRGÃO"])["VALOR TRANSAÇÃO"].agg(["sum"]).reset_index().sort_values(by = "sum",ascending = False)

# %%
df_dia_mais_gasto4.rename(columns ={"sum":"Valor Gasto"},inplace=True)

# %%
df_dia_mais_gasto4["Percentual"] = round((df_dia_mais_gasto4["Valor Gasto"] * 100) / df_dia_mais_gasto3["VALOR TRANSAÇÃO"].sum(),2)

# %%
plt.figure(figsize=(12,6))
explode = [0.05, 0, 0, 0,0]
plt.pie(df_dia_mais_gasto4["Percentual"], labels = df_dia_mais_gasto4["NOME ÓRGÃO"],
    autopct="%1.1f%%",
    startangle=140,
    explode=explode,
    pctdistance=0.85)
plt.title("Gasto por cada orgão do Ministério da Defesa")
plt.show()

# %%
df_dia_mais_gasto4
# Out:
#                                           NOME ÓRGÃO  Valor Gasto  Percentual
# 1                                COMANDO DO EXERCITO     15302.45       50.58
# 2                                  FUNDO DO EXERCITO      8703.11       28.77
# 0                             COMANDO DA AERONAUTICA      4810.54       15.90
# 4  MINISTERIO DA DEFESA - UNIDADES COM VÍNCULO DI...      1018.16        3.37
# 3             INDUSTRIA DE MATERIAL BELICO DO BRASIL       416.85        1.38

# %% [raw]
# O Ministério da Defesa no dia 21/6 gastou R$ 30.251,11 sendo que 50,58% (R$15.302,45) desse valor foi destinado ao Comando do Exercito.

# %%
df_dia_mais_gasto5 = df_dia_mais_gasto3.groupby(["NOME ÓRGÃO","NOME FAVORECIDO"])["VALOR TRANSAÇÃO"].agg(["sum"]).reset_index().sort_values(by = "sum",ascending = False)

# %%
df_dia_mais_gasto5.rename(columns ={"sum":"Valor Gasto"},inplace=True)

# %%
df_dia_mais_gasto5
# Out:
#                                            NOME ÓRGÃO  \
# 12                                COMANDO DO EXERCITO
# 46                                  FUNDO DO EXERCITO
# 20                                COMANDO DO EXERCITO
# 7                              COMANDO DA AERONAUTICA
# 9                              COMANDO DA AERONAUTICA
# 18                                COMANDO DO EXERCITO
# 43                                  FUNDO DO EXERCITO
# 0                              COMANDO DA AERONAUTICA
# 32                                COMANDO DO EXERCITO
# 42                                  FUNDO DO EXERCITO
# 8                              COMANDO DA AERONAUTICA
# 39                                  FUNDO DO EXERCITO
# 33                                COMANDO DO EXERCITO
# 31                                COMANDO DO EXERCITO
# 2                              COMANDO DA AERONAUTICA
# 54  MINISTERIO DA DEFESA - UNIDADES COM VÍNCULO DI...
# 29                                COMANDO DO EXERCITO
# 6                              COMANDO DA AERONAUTICA
# 56  MINISTERIO DA DEFESA - UNIDADES COM VÍNCULO DI...
# 4                              COMANDO DA AERONAUTICA
# 45                                  FUNDO DO EXERCITO
# 3                              COMANDO DA AERONAUTICA
# 55  MINISTERIO DA DEFESA - UNIDADES COM VÍNCULO DI...
# 17                                COMANDO DO EXERCITO
# 35                                  FUNDO DO EXERCITO
# 11                                COMANDO DO EXERCITO
# 40                                  FUNDO DO EXERCITO
# 57  MINISTERIO DA DEFESA - UNIDADES COM VÍNCULO DI...
# 30                                COMANDO DO EXERCITO
# 14                                COMANDO DO EXERCITO
# 36                                  FUNDO DO EXERCITO
# 13                                COMANDO DO EXERCITO
# 23                                COMANDO DO EXERCITO
# 21                                COMANDO DO EXERCITO
# 51             INDUSTRIA DE MATERIAL BELICO DO BRASIL
# 47                                  FUNDO DO EXERCITO
# 19                                COMANDO DO EXERCITO
# 26                                COMANDO DO EXERCITO
# 48             INDUSTRIA DE MATERIAL BELICO DO BRASIL
# 16                                COMANDO DO EXERCITO
# 50             INDUSTRIA DE MATERIAL BELICO DO BRASIL
# 52             INDUSTRIA DE MATERIAL BELICO DO BRASIL
# 15                                COMANDO DO EXERCITO
# 38                                  FUNDO DO EXERCITO
# 1                              COMANDO DA AERONAUTICA
# 49             INDUSTRIA DE MATERIAL BELICO DO BRASIL
# 10                                COMANDO DO EXERCITO
# 27                                COMANDO DO EXERCITO
# 22                                COMANDO DO EXERCITO
# 5                              COMANDO DA AERONAUTICA
# 44                                  FUNDO DO EXERCITO
# 58  MINISTERIO DA DEFESA - UNIDADES COM VÍNCULO DI...
# 37                                  FUNDO DO EXERCITO
# 24                                COMANDO DO EXERCITO
# 25                                COMANDO DO EXERCITO
# 41                                  FUNDO DO EXERCITO
# 28                                COMANDO DO EXERCITO
# 53             INDUSTRIA DE MATERIAL BELICO DO BRASIL
# 34                                  FUNDO DO EXERCITO
#
#                                       NOME FAVORECIDO  Valor Gasto
# 12                AZUL LINHAS AEREAS BRASILEIRAS S.A.      6932.75
# 46                                  SN. SONG - EIRELI      5596.84
# 20                             GOL LINHAS AEREAS S.A.      3779.56
# 7                                       NAO SE APLICA      1010.00
# 9                                      SEM INFORMACAO       967.54
# 18                             FLORENCA CAMINHOES S/A       852.13
# 43                        PROENCA CARVALHO & CIA LTDA       800.00
# 0                     AMATEL MADEIRAS E TELHAS EIRELI       770.00
# 32                                     SEM INFORMACAO       743.01
# 42                         OCEANAIR LINHAS AEREAS S/A       721.58
# 8                REVILLE COMERCIO E REFRIGERACAO LTDA       711.00
# 39                             GOL LINHAS AEREAS S.A.       573.44
# 33                             TAM LINHAS AEREAS S/A.       534.70
# 31                          RESTAURANTE SATELITE LTDA       501.00
# 2         ATO - ASSISTENCIA TECNICA ODONTOLOGICA LTDA       499.20
# 54  ESTRUTURA CENTER COMERCIO DE MATERIAL DE CONST...       341.00
# 29               POSTO ALDO SAO JOSE DOS PINHAIS LTDA       327.72
# 6                              MARTINS E FERRARI LTDA       282.00
# 56                             POSTO SANTO AMARO LTDA       268.66
# 4     LEROY MERLIN COMPANHIA BRASILEIRA DE BRICOLAGEM       249.80
# 45                                     SEM INFORMACAO       227.25
# 3                            LAMBERTI E BRANDOLT LTDA       221.00
# 55        J.N.COMERCIO DE DERIVADOS DE PETROLEO LTDA.       205.50
# 17                          CHURRASCARIA SARTORI LTDA       203.52
# 35                              AUTO POSTO VIANA LTDA       201.38
# 11                         AUTO POSTO PETROMONTE LTDA       201.25
# 40                                  M M PETROLEO LTDA       200.00
# 57  R F DISTRIBUIDORA DE VIDROS ALUMINIOS E FERRAG...       168.00
# 30                                  POSTO SEABRA LTDA       165.01
# 14               BIGOLIN MATERIAIS DE CONSTRUCAO LTDA       141.01
# 36                             AUTOPOSTO TABOCAS LTDA       135.63
# 13                   BAZAR O AMIGAO DE GUADALUPE LTDA       119.96
# 23                              J A SOBRAL & CIA LTDA       112.38
# 21              HELIO CAVALCANTE DA SILVA 01260903516       110.00
# 51                     MARAJO FERRAGENS COMERCIO LTDA       100.00
# 47                             VULCANIZACAO ROSA LTDA       100.00
# 19       FURUKAWA COMBUSTIVEIS & PARTICIPACOES EIRELI       100.00
# 26                    MECS BORRACHAS E PLASTICOS LTDA        99.50
# 48                    CR MAQUINAS E EQUIPAMENTOS LTDA        91.00
# 16                          CATIA ISOLINA ROCHA ALVES        88.50
# 50                      HP SERVICOS E MANUTENCAO LTDA        83.65
# 52                                      NAO SE APLICA        80.00
# 15                               CASSIO XAVIER BARROS        77.13
# 38                             COELHO E CARVALHO LTDA        64.00
# 1               ANDECON LOCADORA DE EQUIPAMENTOS LTDA        60.00
# 49              HASSAN GEORGES EL MOUALLEM & CIA LTDA        59.80
# 10           AGROSERRA - MAQUINAS E EQUIPAMENTOS LTDA        58.00
# 27                            PAX SUPERMERCADOS LTDA.        49.95
# 22                         I. DE F. CRUZETA DE MATTOS        46.00
# 5                            M C M DA SILVEIRA EIRELI        40.00
# 44  SARF RESTAURANTE, HOTEL E LOJA DE CONVENIENCIA...        35.50
# 58  TERRA UTIL -COMERCIO DE MAQUINAS, FERRAMENTAS ...        35.00
# 37                          CHURRASCARIA REFORCO LTDA        29.99
# 24                             MAURO HEISS & CIA LTDA        23.25
# 25  MEC FIX COMERCIO DE PARAFUSOS E ELEMENTOS DE F...        21.12
# 41    MEIRELES COMERCIO DE PRODUTOS ALIMENTICIOS LTDA        16.50
# 28                PIERONI COMERCIO DE AUTO PECAS LTDA        15.00
# 53                                     SEM INFORMACAO         2.40
# 34                              ARSENAL BAT BOOT LTDA         1.00

# %%
percentual_gasto_defesa2 = (6932.75 * 100) / 15302.45
round(percentual_gasto_defesa2,2)
# Out:
# 45.3

# %% [raw]
# Dos R$ 15.302,45 gasto pelo Comando do Exercito 45.3% (R$6.932,75) foram gasto com a AZUL LINHAS AEREAS BRASILEIRAS S.A.

# %%
df["TRANSAÇÃO"].value_counts()
# Out:
# COMPRA A/V - R$ - APRES              7838
# Informações protegidas por sigilo    1739
# SAQUE CASH/ATM BB                    1636
# COMPRA A/V - INT$ - APRES              30
# SAQUE - INT$ - APRES                   17
# Name: TRANSAÇÃO, dtype: int64

# %%
mapeamento = {
"COMPRA A/V - R$ - APRES":"Compra à vista no Brasil",    
"Informações protegidas por sigilo":"Gasto Sigiloso",
"SAQUE CASH/ATM BB":"Saque efetuado no Banco do Brasil",                  
"COMPRA A/V - INT$ - APRES":"Compra à vista no exterior",         
"SAQUE - INT$ - APRES":"Saque efetuado no exterior"}

# %%
df["TIPO DE TRANSAÇÃO"] = df["TRANSAÇÃO"].map(mapeamento)

# %%
df.isnull().sum()
# Out:
# CÓDIGO ÓRGÃO SUPERIOR     0
# NOME ÓRGÃO SUPERIOR       0
# CÓDIGO ÓRGÃO              0
# NOME ÓRGÃO                0
# CÓDIGO UNIDADE GESTORA    0
# NOME UNIDADE GESTORA      0
# CPF PORTADOR              0
# NOME PORTADOR             0
# CNPJ OU CPF FAVORECIDO    0
# NOME FAVORECIDO           0
# TRANSAÇÃO                 0
# DATA TRANSAÇÃO            0
# VALOR TRANSAÇÃO           0
# TIPO DE TRANSAÇÃO         0
# dtype: int64

# %%
plt.figure(figsize=(16,8))
ax = sns.countplot(x = "TIPO DE TRANSAÇÃO",data = df)
ax.bar_label(ax.containers[0], fontsize=12, color='black', padding=5)
plt.xlabel("")
plt.ylabel("Quantidade")
plt.title("Quantidade de Transações por tipo")
plt.show()

# %% [markdown]
# Muitas transações feitas no Brasil com compras a vista em relação a outros tipos de transação, portanto vamos identificar quanto em valor total esses tipos de transações representa.

# %%
df_transacao = df.groupby("TIPO DE TRANSAÇÃO")["VALOR TRANSAÇÃO"].agg(["sum","count"]).reset_index().sort_values(by="sum",ascending=False)

# %%
df_transacao.rename(columns ={"sum":"Valor Total","count":"Transação"},inplace=True)

# %%
df_transacao
# Out:
#                    TIPO DE TRANSAÇÃO  Valor Total  Transação
# 2                     Gasto Sigiloso   1749347.32       1739
# 0           Compra à vista no Brasil   1741449.33       7838
# 3  Saque efetuado no Banco do Brasil    526561.00       1636
# 4         Saque efetuado no exterior      8968.54         17
# 1         Compra à vista no exterior      7098.08         30

# %%
df_transacao["Percentual de Transação"] = round((df_transacao["Transação"] * 100) / df_transacao["Transação"].sum(),2)

# %%
df_transacao
# Out:
#                    TIPO DE TRANSAÇÃO  Valor Total  Transação  \
# 2                     Gasto Sigiloso   1749347.32       1739
# 0           Compra à vista no Brasil   1741449.33       7838
# 3  Saque efetuado no Banco do Brasil    526561.00       1636
# 4         Saque efetuado no exterior      8968.54         17
# 1         Compra à vista no exterior      7098.08         30
#
#    Percentual de Transação
# 2                    15.44
# 0                    69.61
# 3                    14.53
# 4                     0.15
# 1                     0.27

# %%
plt.figure(figsize=(15,12))
ax = sns.barplot(
    x="Percentual de Transação",
    y="TIPO DE TRANSAÇÃO",
    data=df_transacao
)
ax.bar_label(ax.containers[0], fontsize=12, color="black", padding=5)
plt.ylabel("")
plt.title("Percentual de Transação por tipo de Transação")
plt.show()

# %% [markdown]
# Compras vista efetuada no Brasil representa 70% de todas as transações feitas

# %%
df_transacao2 = df_transacao.loc[[0,2]].copy()

# %%
df_transacao2["Valor Total Formatado"] = df_transacao2["Valor Total"] / 1_000_000

# %%
plt.figure(figsize=(20,14))
ax = sns.barplot(
    x="Valor Total Formatado",
    y="TIPO DE TRANSAÇÃO",
    data=df_transacao2
)
ax.bar_label(ax.containers[0], fontsize=12, color="black", padding=5)
plt.xlabel("Valor total em milhões")
plt.title("Compras à vista no Brasil x Gasto sigiloso")
plt.show()

# %%
volume_mais_transacao = 69.61 - 15.44
volume_mais_transacao
# Out:
# 54.17

# %% [markdown]
# Mesmo compras à vista no Brasil tendo um volume de mais de 54% sobre os gastos sigilosos, o valor total de gastos sigilosos ultrapassa as compras feitas no Brasil

# %%
df_transacao3 = df.groupby(["NOME ÓRGÃO SUPERIOR","TIPO DE TRANSAÇÃO"])["VALOR TRANSAÇÃO"].agg(["sum","count"]).reset_index()

# %%
df_transacao3.sort_values(by="sum",ascending=False,inplace=True)

# %%
df_transacao3.rename(columns={"sum":"Valor Total","count":"Transações"}, inplace = True)

# %%
#Gasto total transações sigilosas
gasto_total_sigiloso = df["VALOR TRANSAÇÃO"][df["TIPO DE TRANSAÇÃO"] == "Gasto Sigiloso"].sum()

# %%
df_transacao3["Percentual"] = round((df_transacao3["Valor Total"] * 100) / gasto_total_sigiloso,2)

# %%
df_transacao3
# Out:
#                               NOME ÓRGÃO SUPERIOR  \
# 27                          MINISTERIO DA JUSTICA
# 47                       PRESIDENCIA DA REPUBLICA
# 18                         MINISTERIO DA EDUCACAO
# 9    MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO
# 16                           MINISTERIO DA DEFESA
# 8    MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO
# 2    MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO
# 31                            MINISTERIO DA SAUDE
# 20                          MINISTERIO DA FAZENDA
# 37                  MINISTERIO DE MINAS E ENERGIA
# 45                       PRESIDENCIA DA REPUBLICA
# 10  MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES
# 42                         MINISTERIO DO TRABALHO
# 4    MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO
# 24              MINISTERIO DA INTEGRACAO NACIONAL
# 40                    MINISTERIO DO MEIO AMBIENTE
# 26                          MINISTERIO DA JUSTICA
# 48                       PRESIDENCIA DA REPUBLICA
# 12      MINIST.DOS TRANSP.,PORTOS E AVIACAO CIVIL
# 17                           MINISTERIO DA DEFESA
# 0                        ADVOCACIA-GERAL DA UNIAO
# 44               MINISTERIO DO TRABALHO E EMPREGO
# 23                          MINISTERIO DA FAZENDA
# 19                         MINISTERIO DA EDUCACAO
# 34                         MINISTERIO DAS CIDADES
# 6   MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS
# 5    MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO
# 38           MINISTERIO DO DESENVOLVIMENTO SOCIAL
# 7   MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS
# 22                          MINISTERIO DA FAZENDA
# 14                          MINISTERIO DA CULTURA
# 28                          MINISTERIO DA JUSTICA
# 43                         MINISTERIO DO TRABALHO
# 1                        ADVOCACIA-GERAL DA UNIAO
# 41                    MINISTERIO DO MEIO AMBIENTE
# 21                          MINISTERIO DA FAZENDA
# 32                            MINISTERIO DA SAUDE
# 11  MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES
# 46                       PRESIDENCIA DA REPUBLICA
# 33              MINISTERIO DA TRANSPARENCIA E CGU
# 29      MINISTERIO DA JUSTICA E SEGURANçA PUBLICA
# 25              MINISTERIO DA INTEGRACAO NACIONAL
# 13      MINIST.DOS TRANSP.,PORTOS E AVIACAO CIVIL
# 15                          MINISTERIO DA CULTURA
# 39           MINISTERIO DO DESENVOLVIMENTO SOCIAL
# 3    MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO
# 49                       PRESIDENCIA DA REPUBLICA
# 36             MINISTERIO DAS RELACOES EXTERIORES
# 30      MINISTERIO DA JUSTICA E SEGURANçA PUBLICA
# 35                         MINISTERIO DAS CIDADES
#
#                     TIPO DE TRANSAÇÃO  Valor Total  Transações  Percentual
# 27                     Gasto Sigiloso    896070.59        1154       51.22
# 47                     Gasto Sigiloso    846276.73         576       48.38
# 18           Compra à vista no Brasil    445123.82        1841       25.45
# 9   Saque efetuado no Banco do Brasil    379191.00        1160       21.68
# 16           Compra à vista no Brasil    355930.13        1111       20.35
# 8            Compra à vista no Brasil    155952.88        1206        8.91
# 2            Compra à vista no Brasil    118469.96         630        6.77
# 31           Compra à vista no Brasil    111408.81         356        6.37
# 20           Compra à vista no Brasil    108545.07         580        6.20
# 37           Compra à vista no Brasil     79762.89         409        4.56
# 45           Compra à vista no Brasil     75659.16         320        4.32
# 10           Compra à vista no Brasil     58355.10         264        3.34
# 42           Compra à vista no Brasil     50067.25         273        2.86
# 4   Saque efetuado no Banco do Brasil     35909.00         115        2.05
# 24           Compra à vista no Brasil     32399.96         171        1.85
# 40           Compra à vista no Brasil     29550.26          62        1.69
# 26           Compra à vista no Brasil     26578.81         105        1.52
# 48  Saque efetuado no Banco do Brasil     24880.00          63        1.42
# 12           Compra à vista no Brasil     19226.22         111        1.10
# 17  Saque efetuado no Banco do Brasil     18486.00          59        1.06
# 0            Compra à vista no Brasil     17448.14         131        1.00
# 44           Compra à vista no Brasil     16351.88          76        0.93
# 23  Saque efetuado no Banco do Brasil     15549.00          66        0.89
# 19  Saque efetuado no Banco do Brasil     14189.00          61        0.81
# 34           Compra à vista no Brasil     13005.16          68        0.74
# 6            Compra à vista no Brasil      8798.02          34        0.50
# 5          Saque efetuado no exterior      8343.04          15        0.48
# 38           Compra à vista no Brasil      8051.07          30        0.46
# 7   Saque efetuado no Banco do Brasil      7007.00          25        0.40
# 22                     Gasto Sigiloso      7000.00           9        0.40
# 14           Compra à vista no Brasil      6348.54          38        0.36
# 28  Saque efetuado no Banco do Brasil      5335.00          18        0.30
# 43  Saque efetuado no Banco do Brasil      4705.00          13        0.27
# 1   Saque efetuado no Banco do Brasil      4600.00          15        0.26
# 41  Saque efetuado no Banco do Brasil      4020.00           5        0.23
# 21         Compra à vista no exterior      3758.58           1        0.21
# 32  Saque efetuado no Banco do Brasil      3380.00           8        0.19
# 11  Saque efetuado no Banco do Brasil      3050.00           7        0.17
# 46         Compra à vista no exterior      2163.75          23        0.12
# 33           Compra à vista no Brasil      2011.86           6        0.12
# 29           Compra à vista no Brasil      1831.00           7        0.10
# 25  Saque efetuado no Banco do Brasil      1750.00           9        0.10
# 13  Saque efetuado no Banco do Brasil      1660.00           5        0.09
# 15  Saque efetuado no Banco do Brasil      1480.00           4        0.08
# 39  Saque efetuado no Banco do Brasil      1100.00           2        0.06
# 3          Compra à vista no exterior      1082.18           5        0.06
# 49         Saque efetuado no exterior       625.50           2        0.04
# 36           Compra à vista no Brasil       573.34           9        0.03
# 30  Saque efetuado no Banco do Brasil       270.00           1        0.02
# 35         Compra à vista no exterior        93.57           1        0.01

# %% [raw]
# Dos R$ 1.749.347,32 gasto com transações sigilosas, 99% dessas transações são representadas por dois orgãos superiores (Ministerio da Justiça e Presidencia da Republica) com gastos expressivos em transações sigilosas

# %%
df["SIGILOSO"] = np.where(df["TIPO DE TRANSAÇÃO"] == "Gasto Sigiloso","Sim","Não")

# %%
filtro = df["SIGILOSO"].value_counts().copy()

# %%
df2 = pd.DataFrame(filtro).reset_index()

# %%
df2.rename(columns = {"index":"SIGILOSO","SIGILOSO":"QUANTIDADE"},inplace=True)

# %%
plt.figure(figsize=(12,6))
plt.pie(df2["QUANTIDADE"], labels = df2["SIGILOSO"],
    autopct="%1.1f%%",
    startangle=140,
    pctdistance=0.85)
plt.legend()
plt.title("Transações Sigilosas")
plt.show()

# %%
flitro2 = df.groupby("SIGILOSO")["VALOR TRANSAÇÃO"].agg(["sum","count"]).reset_index()

# %%
df2["VALOR TOTAL"] = flitro2["sum"]

# %%
df2
# Out:
#   SIGILOSO  QUANTIDADE  VALOR TOTAL
# 0      Não        9521   2284076.95
# 1      Sim        1739   1749347.32

# %%
df2["PERCENTUAL"] = round((df2["QUANTIDADE"] * 100)/ df.shape[0],2)

# %%
df2["PERCENTUAL DIVIDO"] = df2["PERCENTUAL"] / 100

# %% [markdown]
# Qual a probabilidade que no proximo mês (julho) a quantidade de transações sigilosas seja maior que 1700?
# Supondo que nesse mês tenha 11 mil transações.

# %%
n = 11000
p = df2.loc[1,"PERCENTUAL DIVIDO"]
k = 1700

# %%
# Calculando a probabilidade
prob_menor = binom.cdf(k, n, p) # Calculo da probabilidade de ser menor
prob_maior = 1 - prob_menor # Calculo da probabilidade ser maior que 1700

# %%
prob_maior
# Out:
# 0.47669769263429285

# %%
print(f"Tem uma probabilidade de {prob_maior * 100:.2f}%")
# Out:
# Tem uma probabilidade de 47.67%

# %% [raw]
# Tem uma probabilidade de 47% que no proximo mês (julho) a quantidade de transações sigilosas seja maior que 1700
